# %%
import os
import pandas as pd 
import numpy as np
import csv

# %%
cust=pd.read_csv("Customers.csv",encoding= 'unicode_escape')

# %%
cust.head(5)
# Out:
#    Customer_ID Gender  First_Date First_region  First_state        First_city  \
# 0    129609144      M    20130130         West      Gujarat             Surat
# 1    129627580      M    20130129        North        Delhi             Delhi
# 2    130363481      M    20130221         West      Gujarat             Surat
# 3     49817480      M    20130222         West  Maharashtra  Pimpri-Chinchwad
# 4    126343829      F    20130301        North        Delhi             Delhi
#
#    Recent_Date Last_region   Last_state         Last_city  Customer_Value  \
# 0     20130216        West      Gujarat             Surat          2032.0
# 1     20130129       North        Delhi             Delhi          1709.0
# 2     20130221        West      Gujarat             Surat           523.0
# 3     20130222        West  Maharashtra  Pimpri-Chinchwad          5132.0
# 4     20130301       North        Delhi             Delhi          1008.0
#
#    Buy_Times  Points_Earned  Points_Redeemed
# ...

# %%
cust.shape
# Out:
# (10000, 14)

# %%
cust.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
cust.columns
# Out:
# Index(['Customer_ID', 'Gender', 'First_Date', 'First_region', 'First_state',
#        'First_city', 'Recent_Date', 'Last_region', 'Last_state', 'Last_city',
#        'Customer_Value', 'Buy_Times', 'Points_Earned', 'Points_Redeemed'],
#       dtype='object')

# %%
cust.dtypes.ndim
# Out:
# 1

# %%
cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Customer_ID      10000 non-null  int64
#  1   Gender           9986 non-null   object
#  2   First_Date       10000 non-null  int64
#  3   First_region     9979 non-null   object
#  4   First_state      9983 non-null   object
#  5   First_city       10000 non-null  object
#  6   Recent_Date      10000 non-null  int64
#  7   Last_region      10000 non-null  object
#  8   Last_state       10000 non-null  object
#  9   Last_city        10000 non-null  object
#  10  Customer_Value   9964 non-null   float64
#  11  Buy_Times        10000 non-null  int64
#  12  Points_Earned    9979 non-null   float64
#  13  Points_Redeemed  9988 non-null   float64
# dtypes: float64(3), int64(4), object(7)
# memory usage: 1.1+ MB

# %%
cust["Customer_Value"].isnull().sum()/cust["Customer_Value"].count()*100
# Out:
# 0.3613006824568446

# %%
subset1=cust.drop_duplicates(inplace=False)
subset2=cust.duplicated()

# %%
new_cust=cust[cust["Customer_Value"]>10000]
new_cust.head(5)
# Out:
#     Customer_ID Gender  First_Date First_region    First_state  \
# 14      1610085      F    20120103        North          Delhi
# 15      7518872      M    20120104        North  Uttar Pradesh
# 18     63508964      M    20120106         West    Maharashtra
# 19     23667984      F    20120107         West    Maharashtra
# 20     84634600      M    20120108        South      Karnataka
#
#           First_city  Recent_Date Last_region     Last_state  \
# 14             Delhi     20121013       North          Delhi
# 15            Kanpur     20130123       North  Uttar Pradesh
# 18  Pimpri-Chinchwad     20130222        West    Maharashtra
# 19            Nagpur     20130313        West    Maharashtra
# 20         Bangalore     20130307       South      Karnataka
#
#            Last_city  Customer_Value  Buy_Times  Points_Earned  \
# 14             Delhi       10380.199          6         1189.0
# 15            Kanpur       14587.000          6          865.0
# ...

# %%
cust["customer value segment"]=pd.cut(cust['Customer_Value'], bins=[0, 10000, 25000, 60000000], include_lowest=True, labels=['Low Value Segment', 'Medium Value Segment', 'High Value Segment'])
cust.head(5)
# Out:
#    Customer_ID Gender  First_Date First_region  First_state        First_city  \
# 0    129609144      M    20130130         West      Gujarat             Surat
# 1    129627580      M    20130129        North        Delhi             Delhi
# 2    130363481      M    20130221         West      Gujarat             Surat
# 3     49817480      M    20130222         West  Maharashtra  Pimpri-Chinchwad
# 4    126343829      F    20130301        North        Delhi             Delhi
#
#    Recent_Date Last_region   Last_state         Last_city  Customer_Value  \
# 0     20130216        West      Gujarat             Surat          2032.0
# 1     20130129       North        Delhi             Delhi          1709.0
# 2     20130221        West      Gujarat             Surat           523.0
# 3     20130222        West  Maharashtra  Pimpri-Chinchwad          5132.0
# 4     20130301       North        Delhi             Delhi          1008.0
#
# ...

# %%
cust['average revenue per trip']=''
cust['balance points']=''

# %%
byLastCity=cust.groupby('Last_city')
byLastCity.sum()/cust.sum()*100
# Out:
#                Buy_Times  Customer_ID  Customer_Value  First_Date  First_city  \
# Last_city
# Agartala        0.029210     0.042976        0.018824    0.029998         NaN
# Agra            0.292099     0.086638        0.268937    0.129990         NaN
# Ahmedabad       6.418870     6.033040        6.063446    6.210004         NaN
# Aligarh         0.065722     0.099170        0.025499    0.089993         NaN
# Allahabad       0.012779     0.024711        0.004467    0.019998         NaN
# ...                  ...          ...             ...         ...         ...
# Vasai-Virar     0.147875     0.124380        0.085952    0.149993         NaN
# Vijayawada      0.368775     0.172128        0.394730    0.199985         NaN
# Visakhapatnam   0.996787     1.345871        1.042271    1.169995         NaN
# Vizianagaram    0.021907     0.000054        0.018434    0.009999         NaN
# Warangal        0.012779     0.013700        0.008033    0.009999         NaN
#
# ...

# %%
byLastState=cust.groupby('Last_state')
byLastState.sum()/cust.sum()*100
# Out:
#                    Buy_Times  Customer_ID  Customer_Value  First_Date  \
# Last_state
# Andhra Pradesh      1.422156     1.569813        1.472727    1.419976
# Assam               1.520739     0.314616        1.557344    0.299983
# Bihar               0.290273     0.233990        0.260640    0.249985
# Chandigarh          0.043815     0.066602        0.032769    0.060000
# Chhattisgarh        0.010954     0.029001        0.005322    0.019999
# Delhi               9.617351    10.437696        8.591248   10.370103
# Gujarat            34.440266    32.286599       37.580002   33.779992
# Haryana             0.142398     0.011856        0.141499    0.029998
# Jammu and Kashmir   0.007302     0.014609        0.004879    0.009999
# Jharkhand           0.228202     0.267794        0.245649    0.269983
# Karnataka           5.993501     6.581160        5.330100    6.449998
# Kerala              0.136921     0.100300        0.100897    0.099997
# ...

# %%
byLastRegion=cust.groupby('Last_region')
byLastRegion.sum()/cust.sum()*100
# Out:
#              Buy_Times  Customer_ID  Customer_Value  First_Date  First_city  \
# Last_region
# East          8.229882     6.388275        7.798658    6.459999         NaN
# North        28.154666    29.645017       27.741557   29.579996         NaN
# South        17.029356    18.781574       15.403798   18.070002         NaN
# West         46.586096    45.185134       49.055986   45.890002         NaN
#
#              Last_city  Last_region  Last_state  Points_Earned  \
# Last_region
# East               NaN          NaN         NaN       7.504864
# North              NaN          NaN         NaN      28.432783
# South              NaN          NaN         NaN      14.461723
# West               NaN          NaN         NaN      49.600630
#
#              Points_Redeemed  Recent_Date
# Last_region
# East               28.639475     6.460082
# North              20.617944    29.579920
# South               9.817177    18.069983
# West               40.925404    45.890015

# %%
byLastCity.describe()
# Out:
#               Customer_ID                                           \
#                     count          mean           std          min
# Last_city
# Agartala              3.0  1.195872e+08  2.868228e+06  116639132.0
# Agra                 13.0  5.563433e+07  5.036590e+07     758785.0
# Ahmedabad           621.0  8.110022e+07  4.936418e+07       4435.0
# Aligarh               9.0  9.198458e+07  2.332187e+07   52820735.0
# Allahabad             2.0  1.031408e+08  1.668726e+07   91341140.0
# ...                   ...           ...           ...          ...
# Vasai-Virar          15.0  6.922061e+07  4.299276e+07     259266.0
# Vijayawada           20.0  7.184543e+07  5.207465e+07       4784.0
# Visakhapatnam       117.0  9.602735e+07  4.148198e+07     433882.0
# Vizianagaram          1.0  4.501610e+05           NaN     450161.0
# Warangal              1.0  1.143661e+08           NaN  114366137.0
#
#                                                                      \
# ...

# %%
byLastState.describe()
# Out:
#                   Customer_ID                                           \
#                         count          mean           std          min
# Last_state
# Andhra Pradesh          142.0  9.228625e+07  4.393309e+07       4784.0
# Assam                    30.0  8.754623e+07  4.284349e+07    5172288.0
# Bihar                    25.0  7.813298e+07  3.959736e+07    1617978.0
# Chandigarh                6.0  9.266493e+07  4.571499e+07    3039638.0
# Chhattisgarh              2.0  1.210498e+08  6.890968e+06  116177131.0
# Delhi                  1037.0  8.402400e+07  4.838559e+07      12937.0
# Gujarat                3378.0  7.978846e+07  4.960479e+07        585.0
# Haryana                   3.0  3.298953e+07  4.537498e+07    6153755.0
# Jammu and Kashmir         1.0  1.219564e+08           NaN  121956398.0
# Jharkhand                27.0  8.279699e+07  4.293121e+07     458827.0
# Karnataka               645.0  8.517657e+07  4.793106e+07      10588.0
# ...
